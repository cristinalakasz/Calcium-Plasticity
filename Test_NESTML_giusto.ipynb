# %%
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['axes.formatter.useoffset'] = False
import matplotlib.pyplot as plt
import nest
import numpy as np
import os
import re

from pynestml.codegeneration.nest_code_generator_utils import NESTCodeGeneratorUtils
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.7.0
#  Built: May 19 2024 15:53:53
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %%
help(NESTCodeGeneratorUtils.generate_code_for)
# Out:
# Help on method generate_code_for in module pynestml.codegeneration.nest_code_generator_utils:
#
# generate_code_for(nestml_neuron_model: str, nestml_synapse_model: Union[str, NoneType] = None, module_name: Union[str, NoneType] = None, target_path: str = 'target', post_ports: Union[List[str], NoneType] = None, mod_ports: Union[List[str], NoneType] = None, logging_level: str = 'WARNING') method of builtins.type instance
#     Generate code for a given neuron and synapse model, passed as a string.
#     The neuron and synapse models can be passed directly as strings in NESTML syntax, or as filenames, in which case the NESTML model is loaded from the given filename.
#
#     Returns
#     -------
#     If a synapse is specified, returns a tuple (module_name, mangled_neuron_name, mangled_synapse_name) containing the names that can be used in ``nest.Install()``, ``nest.Create()`` and ``nest.Connect()`` calls. If no synapse is specified, returns a tuple (module_name, mangled_neuron_name).

# %%
import pynestml
pynestml.__version__
# Out:
# '7.0.2'

# %%
module_name, neuron_model_name, synapse_model_name = NESTCodeGeneratorUtils.generate_code_for(
    nestml_neuron_model="mhill_tononi_neuron.nestml",
    nestml_synapse_model="stdp.nestml", 
    module_name = "PW_module",
    post_ports=["post_spikes", ["rho_in", "rho_GB"]],
    target_path = "target_stdp")
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.7.0
#  Built: May 19 2024 15:53:53
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.
#
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# [17,mhill_tononi_neuron_nestml, WARNING, [80:25;80:25]]: Implicit casting from (compatible) type '1 / ms' to 'real'.
# [18,mhill_tononi_neuron_nestml, WARNING, [83:25;83:25]]: Implicit casting from (compatible) type '1 / ms' to 'real'.
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# [37,stdp_nestml, WARNING, [43:8;43:28]]: Variable 'd' has the same name as a physical unit!
# [62,stdp_nestml, WARNING, [43:8;43:28]]: Variable 'd' has the same name as a physical unit!
# [73,mhill_tononi_neuron_nestml, WARNING, [80:25;80:25]]: Implicit casting from (compatible) type '1 / ms' to 'real'.
# [74,mhill_tononi_neuron_nestml, WARNING, [83:25;83:25]]: Implicit casting from (compatible) type '1 / ms' to 'real'.
# [92,stdp_nestml, WARNING, [43:8;43:28]]: Variable 'd' has the same name as a physical unit!
# [131,stdp_nestml__with_mhill_tononi_neuron_nestml, WARNING, [43:8;43:28]]: Variable 'd' has the same name as a physical unit!
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# WARNING:root:Under certain conditions, the propagator matrix is singular (contains infinities).
# WARNING:root:List of all conditions that result in a singular propagator:
# WARNING:root:	NMDA_Tau_1 = NMDA_Tau_2
# WARNING:root:	AMPA_Tau_1 = AMPA_Tau_2
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ...
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# [188,GLOBAL, ERROR, [214:10;214:10]]: Could not resolve symbol 'r'!
# [189,GLOBAL, ERROR]: No symbol could be resolved for assignment "r = r - 1
# "!
# ---------------------------------------------------------------------------
# TemplateRuntimeError                      Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 module_name, neuron_model_name, synapse_model_name = NESTCodeGeneratorUtils.generate_code_for(
#       2     nestml_neuron_model="mhill_tononi_neuron.nestml",
#       3     nestml_synapse_model="stdp.nestml",
#       4     module_name = "PW_module",
#       5     post_ports=["post_spikes", ["rho_in", "rho_GB"]],
#       6     target_path = "target_stdp")
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/pynestml/codegeneration/nest_code_generator_utils.py:124, in NESTCodeGeneratorUtils.generate_code_for(cls, nestml_neuron_model, nestml_synapse_model, module_name, target_path, post_ports, mod_ports, logging_level)
#     121     uniq_id = str(uuid.uuid4().hex)
#     122     module_name = "nestml_" + uniq_id + "_module"
# --> 124 generate_nest_target(input_path=input_fns,
#     125                      install_path=install_path,
#     126                      logging_level=logging_level,
#     127                      module_name=module_name,
#     128                      target_path=target_path,
#     129                      suffix="_nestml",
#     130                      codegen_opts=codegen_opts)
#     132 if nestml_synapse_model:
#     133     return module_name, mangled_neuron_name, mangled_synapse_name
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/pynestml/frontend/pynestml_frontend.py:267, in generate_nest_target(input_path, target_path, install_path, logging_level, module_name, store_log, suffix, dev, codegen_opts)
#     240 def generate_nest_target(input_path: Union[str, Sequence[str]], target_path: Optional[str] = None,
#     241                          install_path: Optional[str] = None, logging_level="ERROR",
#     242                          module_name=None, store_log: bool = False, suffix: str = "",
#     243                          dev: bool = False, codegen_opts: Optional[Mapping[str, Any]] = None):
#     244     r"""Generate and build code for NEST Simulator.
#     245
#     246     Parameters
#    (...)
#     265         A dictionary containing additional options for the target code generator.
#     266     """
# --> 267     generate_target(input_path, target_platform="NEST", target_path=target_path, logging_level=logging_level,
#     268                     module_name=module_name, store_log=store_log, suffix=suffix, install_path=install_path,
#     269                     dev=dev, codegen_opts=codegen_opts)
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/pynestml/frontend/pynestml_frontend.py:190, in generate_target(input_path, target_platform, target_path, install_path, logging_level, module_name, store_log, suffix, dev, codegen_opts)
#     162 r"""Generate and build code for the given target platform.
#     163
#     164 Parameters
#    (...)
#     185     A dictionary containing additional options for the target code generator.
#     186 """
#     188 configure_front_end(input_path, target_platform, target_path, install_path, logging_level,
#     189                     module_name, store_log, suffix, dev, codegen_opts)
# --> 190 if not process() == 0:
#     191     raise Exception("Error(s) occurred while processing the model")
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/pynestml/frontend/pynestml_frontend.py:476, in process()
#     474 if not errors_occurred:
#     475     models = transform_models(transformers, models)
# --> 476     generate_code(code_generator, models)
#     478     # perform build
#     479     if _builder is not None:
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/pynestml/frontend/pynestml_frontend.py:445, in generate_code(code_generators, models)
#     444 def generate_code(code_generators, models):
# --> 445     code_generators.generate_code(models)
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/pynestml/codegeneration/nest_code_generator.py:233, in NESTCodeGenerator.generate_code(self, models)
#     231 self.analyse_transform_neurons(neurons)
#     232 self.analyse_transform_synapses(synapses)
# --> 233 self.generate_neurons(neurons)
#     234 self.generate_synapses(synapses)
#     235 self.generate_module_code(neurons, synapses)
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/pynestml/codegeneration/code_generator.py:164, in CodeGenerator.generate_neurons(self, neurons)
#     161 from pynestml.frontend.frontend_configuration import FrontendConfiguration
#     163 for neuron in neurons:
# --> 164     self.generate_neuron_code(neuron)
#     165     if not Logger.has_errors(neuron):
#     166         code, message = Messages.get_code_generated(neuron.get_name(), FrontendConfiguration.get_target_path())
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/pynestml/codegeneration/code_generator.py:223, in CodeGenerator.generate_neuron_code(self, neuron)
#     222 def generate_neuron_code(self, neuron: ASTNeuron) -> None:
# --> 223     self.generate_model_code(neuron.get_name(),
#     224                              model_templates=self._model_templates["neuron"],
#     225                              template_namespace=self._get_neuron_model_namespace(neuron),
#     226                              model_name_escape_string="@NEURON_NAME@")
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/pynestml/codegeneration/code_generator.py:216, in CodeGenerator.generate_model_code(self, model_name, model_templates, template_namespace, model_name_escape_string)
#     213     templ_file_base_name = templ_file_base_name + "." + file_extension
#     214 rendered_templ_file_name = os.path.join(FrontendConfiguration.get_target_path(),
#     215                                         templ_file_base_name)
# --> 216 _file = _model_templ.render(template_namespace)
#     217 Logger.log_message(message="Rendering template " + rendered_templ_file_name,
#     218                    log_level=LoggingLevel.INFO)
#     219 with open(rendered_templ_file_name, "w+") as f:
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/jinja2/environment.py:1301, in Template.render(self, *args, **kwargs)
#    1299     return self.environment.concat(self.root_render_func(ctx))  # type: ignore
#    1300 except Exception:
# -> 1301     self.environment.handle_exception()
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/jinja2/environment.py:936, in Environment.handle_exception(self, source)
#     931 """Exception handling helper.  This is used internally to either raise
#     932 rewritten exceptions or return a rendered traceback for the template.
#     933 """
#     934 from .debug import rewrite_traceback_stack
# --> 936 raise rewrite_traceback_stack(source=source)
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/pynestml/codegeneration/resources_nest/point_neuron/@NEURON_NAME@.cpp.jinja2:21, in top-level template code()
#      19 along with NEST.  If not, see <http://www.gnu.org/licenses/>.
#      20 #}
# ---> 21 {%- include "common/NeuronClass.jinja2" %}
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/pynestml/codegeneration/resources_nest/point_neuron/common/NeuronClass.jinja2:722, in top-level template code()
#     720  */
#     721 {%-             endif %}
# --> 722 {%-             include "directives_cpp/Block.jinja2" %}
#     723 {%-         endfor %}
#     724 {%-     endfilter %}
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/pynestml/codegeneration/resources_nest/point_neuron/directives_cpp/Block.jinja2:9, in top-level template code()
#       7 {%- for statement in ast.get_stmts() %}
#       8 {%- with stmt = statement %}
# ----> 9 {%- include "directives_cpp/Statement.jinja2" %}
#      10 {%- endwith %}
#      11 {%- endfor %}
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/pynestml/codegeneration/resources_nest/point_neuron/directives_cpp/Statement.jinja2:14, in top-level template code()
#      12 {%- elif stmt.is_compound_stmt() %}
#      13 {%-   with stmt = stmt.compound_stmt %}
# ---> 14 {%-     include "directives_cpp/CompoundStatement.jinja2" %}
#      15 {%-   endwith %}
#      16 {%- endif %}
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/pynestml/codegeneration/resources_nest/point_neuron/directives_cpp/CompoundStatement.jinja2:8, in top-level template code()
#       6 {%- if stmt.is_if_stmt() %}
#       7 {%-   with ast = stmt.get_if_stmt() %}
# ----> 8 {%-     include "directives_cpp/IfStatement.jinja2" %}
#       9 {%-   endwith %}
#      10 {%- elif stmt.is_for_stmt() %}
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/pynestml/codegeneration/resources_nest/point_neuron/directives_cpp/IfStatement.jinja2:10, in top-level template code()
#       8 {%- filter indent(2, True) %}
#       9 {%-   with ast = ast.get_if_clause().get_block() %}
# ---> 10 {%- include "directives_cpp/Block.jinja2" %}
#      11 {%-   endwith %}
#      12 {%- endfilter %}
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/pynestml/codegeneration/resources_nest/point_neuron/directives_cpp/Block.jinja2:9, in top-level template code()
#       7 {%- for statement in ast.get_stmts() %}
#       8 {%- with stmt = statement %}
# ----> 9 {%- include "directives_cpp/Statement.jinja2" %}
#      10 {%- endwith %}
#      11 {%- endfor %}
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/pynestml/codegeneration/resources_nest/point_neuron/directives_cpp/Statement.jinja2:10, in top-level template code()
#       8 {%- if stmt.is_small_stmt() %}
#       9 {%-   with stmt = stmt.small_stmt %}
# ---> 10 {%-     include "directives_cpp/SmallStatement.jinja2" %}
#      11 {%-   endwith %}
#      12 {%- elif stmt.is_compound_stmt() %}
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/pynestml/codegeneration/resources_nest/point_neuron/directives_cpp/SmallStatement.jinja2:8, in top-level template code()
#       6 {%- if stmt.is_assignment() %}
#       7 {%- with ast = stmt.get_assignment() %}
# ----> 8 {%- include "directives_cpp/Assignment.jinja2" %}
#       9 {%- endwith %}
#      10 {%- elif stmt.is_function_call() %}
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/pynestml/codegeneration/resources_nest/point_neuron/directives_cpp/Assignment.jinja2:10, in top-level template code()
#       8 {%- set lhs_variable_sym = assignments.lhs_variable(ast) %}
#       9 {%- if lhs_variable_sym is none %}
# ---> 10 {{ raise('Symbol with name "%s" could not be resolved' % ast.lhs.get_complete_name()) }}
#      11 {%- endif %}
#      12
#
# File /srv/main-spack-instance-2402/spack/var/spack/environments/ebrains-24-04/.spack-env/view/lib/python3.8/site-packages/pynestml/codegeneration/code_generator.py:63, in CodeGenerator.raise_helper(self, msg)
#      62 def raise_helper(self, msg):
# ---> 63     raise TemplateRuntimeError(msg)
#
# TemplateRuntimeError: Symbol with name "r" could not be resolved

# %% [markdown]
# # Now we can use the new module

# %%
nest.ResetKernel()
nest.Install("PW_module")
duration = 10000 # ms
frequency = 10.0  # Hz
delta_t = 10.0  # ms

neuron_model = "mhill_tononi_neuron_nestml__with_stdp_nestml"
syn_model = "stdp_nestml__with_mhill_tononi_neuron_nestml"

pre_neuron = nest.Create(neuron_model, 1)
post_neuron = nest.Create(neuron_model, 1)


wr = nest.Create("weight_recorder")
nest.SetDefaults(syn_model, {"weight_recorder": wr[0]})
receptors = nest.GetDefaults("mhill_tononi_neuron_nestml__with_stdp_nestml")["receptor_types"]
syn_spec = nest.CollocatedSynapses(
                                    {'synapse_model':syn_model,
                                     'receptor_type':receptors["AMPA"],
                                     }
                                    ,
                                   {
                                    'synapse_model':syn_model,
                                    'receptor_type': receptors["NMDA"],
                                       }
                                   ) 
#nest.Connect(pre_neuron, post_neuron, "one_to_one", "static_synapse")
nest.Connect(pre_neuron, post_neuron, "one_to_one", syn_spec=syn_spec)
synapse = nest.GetConnections(pre_neuron, post_neuron)
nest.SetStatus(synapse, {"Wmax":50.0})

interval = 1000.0 / frequency
spike_times = np.arange(interval, duration, interval)
spike_generator = nest.Create("spike_generator", {"spike_times": spike_times})

if delta_t >= 0:
    delta_pre = 0.0
    delta_post = delta_t

else:
    delta_pre = -1 * delta_t
    delta_post = 0.0

    
syn_spec_spike_pre = nest.CollocatedSynapses(
                                    {'synapse_model':'static_synapse',
                                     'receptor_type': 3,
                                     'weight': 999.0,
                                     'delay': 1.0 + delta_pre,
                                    }
                                   )
syn_spec_spike_post = nest.CollocatedSynapses(
                                    {'synapse_model':'static_synapse',
                                     'receptor_type': 3,
                                     'weight': 999.0,
                                     'delay': 1.0 + delta_post,
                                    }
                                   )
    
nest.Connect(spike_generator, pre_neuron, "one_to_one", syn_spec=syn_spec_spike_pre)
nest.Connect(spike_generator, post_neuron, "one_to_one", syn_spec=syn_spec_spike_post)

sd_1 = nest.Create("spike_recorder")
sd_2 = nest.Create("spike_recorder")
nest.Connect(pre_neuron, sd_1)
nest.Connect(post_neuron, sd_2)

vm_pre = nest.Create("voltmeter")
vm_post = nest.Create("voltmeter")
mm_post = nest.Create("multimeter", 1, {"record_from": ["V_m", "Ca_i", "Ca_star_GB", "rho_GB"], "interval": 1.0})
nest.Connect(vm_pre, pre_neuron)
nest.Connect(vm_post, post_neuron) 
nest.Connect(mm_post, post_neuron)
nest.Simulate(duration)



spikes_pre = sd_1.get(['events'][0])
spikes_post = sd_2.get(['events'][0])
#print(sd.events)
# Out:
# Dec 11 11:39:40 Install [Info]:
#     loaded module PW_module
#
# Dec 11 11:39:40 ConnectionManager [Warning]:
#     New connections created, connection descriptors previously obtained using
#     'GetConnections' are now invalid.
#
# Dec 11 11:39:40 NodeManager::prepare_nodes [Info]:
#     Preparing 9 nodes for simulation.
#
# Dec 11 11:39:40 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 9
#     Simulation time (ms): 10000
#     Number of OpenMP threads: 1
#     Number of MPI processes: 1
# ...
# Dec 11 11:39:41 SimulationManager::run [Info]:
#     Simulation finished.

# %%
fig, ax = plt.subplots(6, figsize = (18,10))

ax[0].plot(vm_pre.events["times"], vm_pre.events["V_m"], color = "b", label = "Pre-synaptic potential")
ax[0].plot(vm_post.events["times"], vm_post.events["V_m"], color = "orange",  label = "Post-synaptic potential")
ax[0].set_title("Post-synaptic neuron Potential")
ax[0].set_ylabel("Vm [mV]")
#ax[0].set_xlim([500,2500])
ax[0].legend()

ax[1].plot(vm_pre.events["times"], vm_pre.events["V_m"], color = "b", label = "Pre-synaptic potential")
ax[1].plot(vm_post.events["times"], vm_post.events["V_m"], color = "orange",  label = "Post-synaptic potential")
ax[1].set_title("Post-synaptic neuron Potential")
ax[1].set_ylabel("Vm [mV]")
ax[1].set_xlim([7700,9500])
ax[1].legend()

ax[2].plot(vm_post.events["times"], mm_post.events["Ca_i"], color='m')
ax[2].set_title("Post-synaptic Calcium Dynamic")
ax[2].set_ylabel("Ca_i")
ax[2].legend()

theta_d=0.006
theta_p=0.001
ax[3].plot(vm_post.events["times"], mm_post.events["Ca_star_GB"], color='green')
ax[3].set_ylabel("Ca_star_GB")
ax[3].set_title("Post-synaptic Calcium Efficacy")
ax[3].axhline(theta_p, color='black', linestyle='--', label="Potentiation Threshold")
ax[3].axhline(theta_d, color='red', linestyle='--', label="Depression Threshold")
ax[3].legend()

ax[4].plot(vm_post.events["times"], mm_post.events["rho_GB"], color='c')
ax[4].set_title("Synapse Efficacy")
ax[4].set_ylabel("rho")
ax[4].legend()

ax[5].plot(wr.events["times"], wr.events["weights"], color = 'r')
ax[5].set_title("STDP")
ax[5].set_ylabel("Weight [nS]")
ax[5].set_xlabel("Time [ms]")

fig.tight_layout()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure()
plt.plot(vm_post.events["times"], vm_post.events["V_m"])
plt.xlim(800.0, 1100.0)
plt.ylabel("Vm [mV]")
plt.xlabel("t [ms]")
plt.title("Post-synaptic neuron Vm: first trial")
plt.show()

plt.figure()
plt.plot(vm_post.events["times"], vm_post.events["V_m"])
plt.xlim(8800.0, 9100.0)
plt.ylabel("Vm [mV]")
plt.xlabel("t [ms]")
plt.title("Post-synaptic neuron Vm: last trial")
plt.show()
plt.figure()
plt.plot(wr.events["times"], wr.events["weights"])
plt.ylabel("weight")
plt.xlabel("t [ms]")
plt.title("Synaptic weight update")
plt.show()

# %%
nest.ResetKernel()
nest.Install("PW_module")
neuron_model = "mhill_tononi_neuron_nestml__with_stdp_nestml"
syn_model = "stdp_nestml__with_mhill_tononi_neuron_nestml"


rate = 5.0
pg = nest.Create("poisson_generator", params={"rate": rate})  # Hz -> spikes/s
neuron = nest.Create(neuron_model)
syn_spec_spike = nest.CollocatedSynapses(
                                    {'synapse_model':"static_synapse",
                                     'receptor_type': 3,
                                     'weight': 999.0,                                    }
                                   )
nest.Connect(pg, neuron, syn_spec=syn_spec_spike)
vm = nest.Create("voltmeter", 1)
mm = nest.Create("multimeter", 1, {"record_from": ["V_m", "Ca_i", "Ca_star_GB", "rho_GB"], "interval": 1.0})
nest.Connect(vm, neuron)
nest.Connect(mm, neuron)
sim_time = 1000.0

nest.Simulate(sim_time)
# Out:
# Dec 11 10:52:13 Install [Info]:
#     loaded module PW_module
#
# Dec 11 10:52:13 NodeManager::prepare_nodes [Info]:
#     Preparing 4 nodes for simulation.
#
# Dec 11 10:52:13 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 4
#     Simulation time (ms): 1000
#     Number of OpenMP threads: 1
#     Number of MPI processes: 1
# hereherehereherehere
# Dec 11 10:52:13 SimulationManager::run [Info]:
#     Simulation finished.

# %%
ev = mm.get("events")
t = ev["times"]
V_m = ev["V_m"]
Ca_i = ev["Ca_i"]
Ca_star = ev["Ca_star_GB"]
rho = ev["rho_GB"]

fig = plt.figure(figsize=(14, 5))

plt.plot(t, V_m, color ='black')
plt.ylabel("$V_{m}$ [mV]")
plt.xlabel("Time (ms)")


plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(3, 1, figsize=(14, 10), sharex=True)

# Plot Ca_i
axes[0].plot(t, Ca_i, color='blue')
axes[0].set_ylabel("Ca_i")
axes[0].set_title("Calcium dynamics")

# Plot Ca_star_GB
theta_d=0.006
theta_p=0.001
axes[1].plot(t, Ca_star, color='green')
axes[1].set_ylabel("Ca_star_GB")

axes[1].axhline(theta_p, color='black', linestyle='--', label="Potentiation Threshold")
axes[1].axhline(theta_d, color='red', linestyle='--', label="Depression Threshold")

axes[1].legend()



# Plot rho_GB
axes[2].plot(t, rho, color='red')
axes[2].set_ylabel("rho_GB")
axes[2].set_xlabel("Time (ms)")

plt.tight_layout()
plt.show()
